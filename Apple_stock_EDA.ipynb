# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/drive/MyDrive/AAPL.csv",index_col='Date')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...                ...         ...         ...         ...         ...
# 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#               Volume
# Date
# 2012-01-03  75555200
# 2012-01-04  65005500
# 2012-01-05  67817400
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2011 entries, 2012-01-03 to 2019-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2011 non-null   float64
#  1   High       2011 non-null   float64
#  2   Low        2011 non-null   float64
#  3   Close      2011 non-null   float64
#  4   Adj Close  2011 non-null   float64
#  5   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 110.0+ KB

# %%
df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean    126.707469   127.827594   125.580258   126.741235   119.505548
# std      50.483753    50.926301    50.124940    50.578369    52.438444
# min      55.424286    57.085712    55.014286    55.790001    48.921928
# 25%      85.882858    86.717858    85.056427    86.202145    75.056679
# 50%     113.050003   114.190002   111.870003   113.050003   105.222908
# 75%     165.190002   167.409996   163.424995   165.245002   160.047111
# max     291.119995   293.970001   288.119995   291.519989   289.522614
#
#              Volume
# count  2.011000e+03
# mean   5.949670e+07
# std    4.683856e+07
# min    1.136200e+07
# 25%    2.758565e+07
# 50%    4.346900e+07
# 75%    7.471030e+07
# max    3.765300e+08

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# There are no missing values and duplicates so the data seems clear so far.

# %%
plt.plot(df['Close'])
plt.show()

# %%
sns.distplot(df['Close'])
# Out:
# <Axes: xlabel='Close', ylabel='Density'>

# %%
df.index=pd.to_datetime(df.index)  

###converting index to Data-time data type
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709  75555200
# 2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536  65005500
# 2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175  67817400
# 2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630  79573200
# 2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932  98506100

# %%
df["month"] = df.Date.dt.strftime("%m") # month extraction
df["year"] = df.Date.dt.strftime("%Y") # year extraction
df["Day"] = df.Date.dt.strftime("%d") # Day extraction
df['week']=df.Date.dt.strftime("%V")
df['quarter']=df.Date.dt.quarter
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...                ...         ...         ...         ...         ...
# 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#               Volume       Date month  year Day week  quarter quarter_y
# Date
# ...

# %%
plt.figure(figsize=(10,3))
sns.lineplot(x="year",y="Close",data=df)
# Out:
# <Axes: xlabel='year', ylabel='Close'>

# %%
plt.figure(figsize=(10,3))
sns.lineplot(x="month",y="Close",data=df)
# Out:
# <Axes: xlabel='month', ylabel='Close'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="quarter",y="Close",data=df,  hue='year')
# Out:
# <Axes: xlabel='quarter', ylabel='Close'>

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=df, x='year',y='Close',hue='quarter')
# Out:
# <Axes: xlabel='year', ylabel='Close'>

# %%
plt.figure(figsize=(15,8))
hm = pd.pivot_table(data=df,values="Close",index="month",columns="year")
sns.heatmap(hm,annot=True,fmt=".3f") #fmt is format of the grid values
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
plt.figure(figsize=(14,8))
plt.subplot(211)
sns.boxplot(x="month",y="Close",data=df)
plt.subplot(212)
sns.boxplot(x="year",y="Close",data=df)
# Out:
# <Axes: xlabel='year', ylabel='Close'>

# %%
# create a density plot
df.Close.plot(kind='kde', figsize=(12,6))
plt.show()

# %%
from pandas.plotting import lag_plot
# create a scatter plot
for i in [1, 4, 8, 12, 16, 20, 24, 38, 32, 36, 40]:
    #plt.figure(figsize=(12,8))
    lag_plot(df.Close, lag=i)
    plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose= seasonal_decompose(df.Close,period=21)
decompose.plot()
plt.rcParams['figure.figsize'] = (30, 15);

# %%
decompose= seasonal_decompose(df.Close,period=63)
decompose.plot()
plt.rcParams['figure.figsize'] = (30, 15);

# %%
decompose= seasonal_decompose(df.Close,period=252)
decompose.plot()
plt.rcParams['figure.figsize'] = (30, 15);

# %% [markdown]
# Data is having seasonality and exponential growth in Trend, so we can say that data is non stationary
# residuals doesn't have much deviation and there is no outliers

# %%
df["Close"].rolling(1, center=False).mean().plot(legend=True, label="Rolling Mean");
print("Mean is:", df["Close"].mean())
# Out:
# Mean is: 126.74123461064147

# %%
from statsmodels.tsa.stattools import adfuller
adf = adfuller(df["Close"])[1]
print(f"p value:{adf.round(4)}", ", Series is Stationary" if adf <0.05 else ", Series is Non-Stationary")
# Out:
# p value:0.9961 , Series is Non-Stationary

# %% [markdown]
# after seeing lag plots, rolling mean and adfuller test
# we can say that data is not stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(df.Close)
plot_pacf(df.Close)
plt.show()

# %%
plot_acf(df.Close.diff(21).dropna())
plot_pacf(df.Close.diff(21).dropna())
plt.show()

# %%
adfuller(df.Close.diff(1).dropna())
# Out:
# (-13.625534323873257,
#  1.7631231987209532e-25,
#  8,
#  2001,
#  {'1%': -3.433622218212895,
#   '5%': -2.8629854902259004,
#   '10%': -2.5675395171404802},
#  8629.540212595413)

# %%
plot_acf(df.Close.diff(1).dropna())
plot_pacf(df.Close.diff(1).dropna())
plt.show()

# %%
plt.rcParams.update({'figure.figsize':(9,9), 'figure.dpi':120})

fig, axes = plt.subplots(3, 2)
axes[0, 0].plot(df.Close); axes[0, 0].set_title('Original Series')
plot_acf(df.Close, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.Close.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.Close.diff().dropna(), ax=axes[1, 1])

# seasonal Differencing
axes[2, 0].plot(df.Close.diff(21)); axes[2, 0].set_title('seasonal Differencing')
plot_acf(df.Close.diff(21).dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# #Train and Test Data separation

# %%
train=df.iloc[:1400,:]
test=df.iloc[1400:,:]

# %% [markdown]
# # MODELS
# ## ARIMA_model
# ## SARIMA_model
# ## DATA_DRIVEN_model
